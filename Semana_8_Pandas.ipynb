# %% [markdown]
# <a href="https://colab.research.google.com/github/vitorcapdeville/alura-data-science/blob/main/Semana_8_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nota: instalar a versão 2.0 do pandas.

# %% [markdown]
# Importando os pacotes necessários

# %%
import pandas as pd

# %% [markdown]
# Lendo o arquivos de dados

# %%
clientes = pd.read_csv("clientes.csv", sep = ";", dtype_backend="numpy_nullable")
clientes.head(5)
# Out:
#    Id  Idade Sexo Estado Civil  Sinistros       Prêmio Categoria     Desconto
# 0   1     64    M        viuvo          0   774.464232    Sênior   697.017809
# 1   2     34    F   divorciado          7  1411.800897    Adulto  1411.800897
# 2   3     84    F   divorciado          2   803.922742    Sênior   803.922742
# 3   4     42    F       casado          2  1142.005576    Adulto  1142.005576
# 4   5     20    M       casado       <NA>   940.051137     Jovem   940.051137

# %%
print(f"Existem {clientes.shape[0]} linhas no arquivo importado.")
# Out:
# Existem 10000 linhas no arquivo importado.

# %%
clientes["Sinistros"] = clientes["Sinistros"].fillna(0)
clientes.head(5)
# Out:
#    Id  Idade Sexo Estado Civil  Sinistros       Prêmio Categoria     Desconto
# 0   1     64    M        viuvo          0   774.464232    Sênior   697.017809
# 1   2     34    F   divorciado          7  1411.800897    Adulto  1411.800897
# 2   3     84    F   divorciado          2   803.922742    Sênior   803.922742
# 3   4     42    F       casado          2  1142.005576    Adulto  1142.005576
# 4   5     20    M       casado          0   940.051137     Jovem   940.051137

# %%
clientes["Prêmio"] = clientes["Prêmio"].round(2)
clientes["Desconto"] = clientes["Desconto"].round(2)
clientes.head(5)
# Out:
#    Id  Idade Sexo Estado Civil  Sinistros   Prêmio Categoria  Desconto
# 0   1     64    M        viuvo          0   774.46    Sênior    697.02
# 1   2     34    F   divorciado          7   1411.8    Adulto    1411.8
# 2   3     84    F   divorciado          2   803.92    Sênior    803.92
# 3   4     42    F       casado          2  1142.01    Adulto   1142.01
# 4   5     20    M       casado          0   940.05     Jovem    940.05

# %%
clientes = clientes.drop("Desconto", axis = 1)
clientes.head(5)
# Out:
#    Id  Idade Sexo Estado Civil  Sinistros   Prêmio Categoria
# 0   1     64    M        viuvo          0   774.46    Sênior
# 1   2     34    F   divorciado          7   1411.8    Adulto
# 2   3     84    F   divorciado          2   803.92    Sênior
# 3   4     42    F       casado          2  1142.01    Adulto
# 4   5     20    M       casado          0   940.05     Jovem

# %%
clientes = clientes.sort_values("Idade").reset_index(drop=True)
clientes.head(5)
# Out:
#      Id  Idade Sexo Estado Civil  Sinistros   Prêmio Categoria
# 0  8550     18    F        viuvo          7  1096.77     Jovem
# 1  4417     18    F        viuvo          0   913.23     Jovem
# 2  1275     18    F   divorciado          2  1062.88     Jovem
# 3  1885     18    F       casado          5  1086.89     Jovem
# 4  4700     18    M        viuvo          1  1126.91     Jovem

# %%
clientes.groupby("Estado Civil", as_index = False).agg({"Sinistros": sum, "Prêmio": sum})
# Out:
#   Estado Civil  Sinistros      Prêmio
# 0       casado       7772  2457538.44
# 1   divorciado       8037  2591592.31
# 2     solteiro       7654   2474958.4
# 3        viuvo       7828  2468433.14

# %%
clientes.Categoria.value_counts()
# Out:
# Categoria
# Sênior    6986
# Adulto    1602
# Jovem     1412
# Name: count, dtype: Int64

# %%
import plotly.express as px
clientes["Sinistros"] = clientes["Sinistros"].astype("category")
fig = px.histogram(clientes, x="Sinistros")
fig.update_layout(bargap=0.2)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="76ca9c58-26a2-42f6-8f12-233dbb668eb5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76ca9c58-26a2-42f6-8f12-233dbb668eb5")) {                    Plotly.newPlot(                        "76ca9c58-26a2-42f6-8f12-233dbb668eb5",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sinistros=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[7,0,2,5,1,6,3,3,1,3,4,2,3,4,5,6,6,0,6,2,2,5,7,1,7,0,2,5,7,4,4,7,0,1,2,7,0,4,1,4,6,0,2,2,4,0,7,0,7,3,5,2,1,7,2,3,0,3,6,7,4,6,4,4,6,0,4,5,6,4,0,0,1,6,1,5,4,1,2,2,3,2,2,0,1,5,5,1,0,3,1,1,7,3,6,0,2,3,1,6,4,3,2,1,7,0,6,1,7,4,5,7,5,0,5,1,4,3,1,0,0,6,1,0,1,3,2,4,1,0,3,0,4,2,0,4,5,5,7,5,4,4,5,1,4,0,5,0,7,0,6,4,7,1,5,3,7,0,5,2,6,6,0,0,4,2,0,4,0,6,0,0,4,5,2,7,0,5,6,1,7,2,1,0,1,2,2,6,5,4,3,0,6,1,3,1,0,3,1,6,4,4,5,3,4,7,4,3,4,3,6,3,0,5,5,0,0,0,0,4,3,0,2,3,4,2,2,0,3,0,2,0,3,0,1,4,7,0,5,2,5,3,0,4,0,2,6,1,3,3,0,7,1,7,6,0,1,5,5,4,4,0,0,6,0,2,2,0,5,3,7,5,0,3,7,5,2,5,6,0,2,2,4,0,0,6,7,0,6,0,6,3,0,3,0,5,5,0,1,0,7,2,3,4,0,4,6,2,1,7,6,3,6,3,0,5,1,3,0,4,5,4,0,1,4,0,0,4,1,7,0,1,4,7,7,3,2,1,5,7,0,6,7,4,0,0,7,7,0,0,1,2,5,2,2,7,3,3,0,4,1,4,2,2,5,0,0,6,1,3,0,1,5,0,0,6,3,2,3,2,1,1,3,7,5,4,5,7,7,7,0,2,7,3,7,6,3,0,3,0,0,0,4,2,3,4,3,7,6,0,2,4,6,5,2,2,2,3,3,0,6,7,2,4,7,0,4,5,3,4,2,1,4,6,5,5,0,0,0,0,7,7,7,3,6,0,7,5,7,1,1,6,3,1,5,7,2,4,7,0,6,3,7,0,4,3,5,0,7,2,4,1,4,3,1,3,1,0,1,5,4,0,3,3,2,4,7,4,4,4,6,0,1,1,7,2,5,6,4,7,2,2,0,4,1,0,7,1,3,5,0,0,2,2,3,0,6,5,2,1,3,0,2,0,2,0,3,2,3,2,0,7,4,2,0,4,7,0,2,3,7,0,0,4,0,0,0,1,7,4,0,0,0,5,1,0,3,4,7,4,7,6,2,5,7,7,6,3,7,2,0,7,7,1,5,3,5,0,4,0,7,4,7,4,6,7,6,6,7,4,5,2,0,4,0,0,5,2,3,0,0,1,0,6,1,2,3,0,0,4,7,0,6,6,2,6,0,6,6,3,7,1,1,4,7,1,0,1,0,6,1,0,6,3,3,7,0,4,0,7,1,7,4,5,1,7,7,0,2,3,0,0,3,7,1,0,2,0,5,0,4,6,6,2,0,0,3,2,5,7,7,2,2,1,3,6,3,0,6,1,3,4,2,4,1,2,2,6,1,6,7,1,4,2,7,1,5,6,6,2,2,0,0,3,2,5,7,0,3,3,0,0,0,3,2,3,5,2,2,0,5,7,3,6,6,1,3,2,6,7,5,5,7,4,7,6,0,0,7,3,1,6,7,7,5,0,3,7,1,7,5,5,7,5,5,7,4,0,4,6,6,3,7,2,2,2,0,0,0,2,6,0,7,6,4,3,1,0,3,6,6,1,5,2,0,5,6,0,5,6,6,4,3,5,0,3,3,3,6,4,2,2,0,6,4,2,7,0,6,0,0,6,0,4,5,5,6,5,1,5,3,2,2,0,6,4,4,4,6,6,0,0,5,3,3,1,5,3,3,7,1,0,3,6,4,0,7,2,6,5,0,4,7,0,5,0,3,6,0,5,3,0,0,4,6,7,5,6,2,2,0,2,7,5,4,5,1,1,0,6,3,5,6,2,4,5,5,7,3,6,0,2,5,0,7,0,0,3,3,4,2,4,7,0,1,6,7,5,3,2,2,3,2,0,4,4,2,5,1,2,0,6,4,0,0,1,5,6,4,3,3,4,4,0,3,5,2,3,5,1,3,7,3,6,2,4,2,0,2,7,1,2,6,5,7,1,1,7,0,1,4,3,1,0,0,4,6,6,0,1,0,0,6,3,0,5,6,1,5,5,7,3,4,7,0,2,2,7,0,7,4,3,6,3,5,1,6,4,5,7,4,7,2,1,1,3,1,4,4,6,1,1,3,7,4,1,4,5,3,4,6,1,3,0,0,3,5,1,0,3,2,2,5,5,2,7,2,0,5,0,0,4,2,5,2,0,7,1,1,2,0,4,7,2,4,2,0,7,1,4,0,4,7,4,0,6,0,5,1,7,3,4,4,3,4,2,2,7,6,2,6,2,4,5,6,3,4,1,5,4,7,6,0,6,2,0,5,7,0,4,2,1,3,5,5,6,6,6,4,3,3,3,1,2,0,3,0,4,4,3,0,3,0,2,4,3,0,5,6,2,6,3,2,5,0,0,0,4,6,7,0,1,3,6,3,6,6,6,4,4,3,4,1,5,4,1,6,3,0,4,1,4,5,2,6,1,4,6,1,6,4,4,0,0,6,1,5,3,5,1,0,6,5,2,4,4,5,5,7,7,0,5,3,0,0,0,5,3,4,3,6,0,5,7,2,1,2,6,7,7,2,4,7,2,0,4,0,3,3,2,3,3,2,7,0,4,4,6,1,2,0,5,0,1,7,1,3,7,3,0,3,3,1,5,3,6,7,0,7,4,5,4,1,6,0,3,0,4,1,7,4,6,1,6,0,2,3,1,7,7,2,0,5,0,0,4,0,3,2,4,1,1,0,6,7,0,4,7,0,0,4,2,0,4,3,3,0,0,2,1,0,0,7,0,4,4,0,7,1,5,0,3,7,2,2,5,6,6,4,2,0,6,4,1,0,3,0,5,4,3,0,4,3,6,1,5,2,5,2,0,4,5,3,6,3,6,7,3,4,6,6,5,0,6,0,0,1,4,1,3,3,4,4,3,5,5,3,0,1,2,6,2,7,1,0,7,6,3,5,3,3,2,2,1,2,0,4,3,5,6,3,6,4,7,0,3,5,4,5,3,7,4,7,5,5,0,0,4,7,0,2,4,3,2,7,6,0,4,0,2,1,6,4,0,6,1,0,7,0,0,5,2,5,0,0,5,1,5,7,5,1,0,2,7,6,7,0,4,2,1,4,1,1,3,7,3,6,0,3,1,0,3,7,2,2,6,0,7,1,1,2,6,0,5,1,2,5,0,1,0,0,5,5,4,6,3,6,5,0,2,6,1,6,0,5,4,1,1,4,0,1,7,2,0,0,2,7,3,0,0,6,5,2,7,7,5,0,0,4,3,4,2,5,6,6,7,3,4,7,6,7,6,1,2,2,2,1,5,3,3,5,5,1,4,5,0,0,6,1,4,0,5,0,0,3,4,1,2,6,5,0,2,3,1,0,0,5,7,6,0,1,7,0,4,4,4,0,4,0,0,4,6,5,6,5,7,7,4,3,2,7,2,3,5,6,0,6,1,0,0,0,3,1,0,0,4, ...
