# %%
import pandas as pd

# %% [markdown]
# Pegando todos os cursos.

# %%
from api import pegar_cursos

cursos = pegar_cursos()
pd.DataFrame.from_records(cursos)
# Out:
#       tempo_estimado                                 slug
# 0                  8  dot-net-6-identity-controle-usuario  \
# 1                 10               dotnet-criando-web-api
# 2                  8        dotnet-relacionando-entidades
# 3                  6                         empresa-agil
# 4                  6         acessibilidade-web-front-end
# ...              ...                                  ...
# 1415               8        wordpress-integracao-whatsapp
# 1416               8             worpress-sites-elementor
# 1417               8    xdebug-ferramenta-debug-profiling
# 1418              20        edicao-de-videos-para-youtube
# 1419              10  youtube-estrategias-sucesso-negocio
#
#                                                    nome
# 0     .NET 6 e Identity: implementando controle de u...
# 1                           .NET 6: criando uma web API
# 2                        .NET 6: relacionando entidades
# 3     A Empresa Ágil: introduzindo o Business Agilit...
# 4     Acessibilidade web parte 1: tornando seu front...
# ...                                                 ...
# 1415  Wordpress: integração whatsapp e internacional...
# 1416                     Wordpress: sites com Elementor
# 1417            XDebug: ferramenta de debug e profiling
# 1418        YouTube: da concepção de um canal ao upload
# 1419  YouTube: estratégias de sucesso para o seu neg...
#
# [1420 rows x 3 columns]

# %% [markdown]
# Pegando detalhe do curso de dotnet.

# %%
from api import pegar_detalhe_curso


curso_dot_net = await pegar_detalhe_curso("dot-net-6-identity-controle-usuario")
pd.DataFrame.from_records([curso_dot_net])
# Out:
#    showable    id                                 slug
# 0      True  2974  dot-net-6-identity-controle-usuario  \
#
#                                                 nome
# 0  .NET 6 e Identity: implementando controle de u...  \
#
#                                      metadescription meta_title
# 0  Entenda como o Identity, integrado ao Entity, ...             \
#
#                                            categoria
# 0  {'nome': 'Programação', 'slug': 'programacao',...  \
#
#                                         subcategoria  quantidade_aulas
# 0  {'slug': 'dotnet', 'nome': '.NET', 'metaTitle'...                 5  \
#
#    minutos_video  ...  carreiras  musicas  depoimentos
# 0            131  ...         []       []           []  \
#
#                                            formacoes  curso_substituto
# 0  [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...              None  \
#
#                                        alunos_ativos parceiros
# 0  {'alunos': [{'username': 'felipeedc29', 'nome'...        []  \
#
#                       requerimentos highlightedExtraField
# 0  [.NET 6: relacionando entidades]                        \
#
#                                       transcriptions
# 0  [{'sectionName': 'Conhecendo o Identity', 'tas...
#
# [1 rows x 33 columns]

# %%
pd.DataFrame.from_records([curso_dot_net])["categoria"][0]
# Out:
# {'nome': 'Programação',
#  'slug': 'programacao',
#  'ordem': 0,
#  'cor': None,
#  'cor_auxiliar': None,
#  'subcategorias': None,
#  'cursos': None,
#  'numero_cursos': None,
#  'guides': None}

# %%
df = pd.json_normalize(curso_dot_net)
categoria = [col for col in df if col.startswith("categoria")]
df[categoria]
# Out:
#   categoria.nome categoria.slug  categoria.ordem categoria.cor
# 0    Programação    programacao                0          None  \
#
#   categoria.cor_auxiliar categoria.subcategorias categoria.cursos
# 0                   None                    None             None  \
#
#   categoria.numero_cursos categoria.guides
# 0                    None             None

# %% [markdown]
# Pegando detalhe de todos os cursos de forma asincrona.

# %%
from api import pegar_detalhes

cursos = pegar_cursos()
cursos_com_detalhe = await pegar_detalhes(cursos)
# cursos_pd = pd.DataFrame.from_records(cursos_com_detalhe)
cursos_pd = pd.json_normalize(cursos_com_detalhe)

# %% [markdown]
# Mostrando as 15 primeiras linhas, todas as colunas.

# %%
pd.options.display.max_columns = None

cursos_pd.head(15)
# Out:
#     showable    id                                               slug
# 0       True  2974                dot-net-6-identity-controle-usuario  \
# 1       True  2792                             dotnet-criando-web-api
# 2       True  2876                      dotnet-relacionando-entidades
# 3       True  1091                                       empresa-agil
# 4       True   805                       acessibilidade-web-front-end
# 5       True   823               acessibilidade-web-front-end-parte-2
# 6       True   735               acessibilidade-web-design-inclusivos
# 7       True  2115      big-query-manipulacao-programatico-linguagens
# 8       True  1224                            mysql-dba-administracao
# 9       True  2584  administracao-oracle-database-gerenciamento-banco
# 10      True  2585  administracao-oracle-database-seguranca-otimiz...
# 11      True   833                                         element-3d
# 12      True   896                           after-effects-personagem
# 13      True  2383  adobe-illustrator-mobile-pecas-redes-sociais-ipad
# 14      True  2528          adobe-illustrator-compondo-pecas-graficas
#
#                                                  nome
# 0   .NET 6 e Identity: implementando controle de u...  \
# 1                         .NET 6: criando uma web API
# 2                      .NET 6: relacionando entidades
# 3   A Empresa Ágil: introduzindo o Business Agilit...
# 4   Acessibilidade web parte 1: tornando seu front...
# 5   Acessibilidade web parte 2: componentes acessí...
# 6         Acessibilidade web: crie designs inclusivos
# 7   Acesso ao Big Query: manipulação programático ...
# 8   Administração do MySQL: segurança e otimização...
# 9   Administração do Oracle Database: criação e ge...
# 10  Administração do Oracle Database: segurança e ...
# 11  Adobe After Effects: animando a partir do Elem...
# 12  Adobe After Effects: construção do personagem ...
# 13  Adobe Illustrator Mobile: criando peças para r...
# 14         Adobe Illustrator: compondo peças gráficas
#
#                                       metadescription meta_title
# 0   Entenda como o Identity, integrado ao Entity, ...             \
# 1   Qualquer pessoa com conhecimento em C# que que...
# 2   Faça este curso e entenda como o Entity Framew...
# 3   Nesse curso você vai aprender os primeiros pas...
# 4   Curso prático para você deixar o front-end do ...
# 5   Depois de deixar o front-end do seu site mais ...       None
# 6   Curso com dicas para você deixar sua interface...       None
# 7   Aprenda como acessar o Big Query através de um...       None
# 8   O DBA (Database Administrator) tem um papel fu...       None
# 9   Oracle é um dos bancos de dados mais utilizado...
# 10  Oracle é um dos bancos de dados mais utilizado...
# 11  Adobe After Effects: animando a partir do Elem...
# 12  Aprenda a construir personagens animáveis usan...       None
# 13  Aprenda a utilizar o Adobe Illustrator Mobile ...       None
# 14  Aprenda a criar materiais de comunicação gráfi...       None
#
#     quantidade_aulas  minutos_video  nota  nota_disponivel
# 0                  5            131   9.3             True  \
# 1                  6            170   9.4             True
# 2                  5            125   9.2             True
# 3                  6             80   9.3             True
# 4                  5            154   9.2             True
# 5                  5            175   9.1             True
# 6                  5            189   9.2             True
# 7                  6            258   8.9             True
# 8                  5            316   9.3             True
# 9                  5            203   9.3             True
# 10                 5            232   9.3             True
# 11                 5            131   9.5             True
# 12                 4             84   9.2             True
# 13                 4            111   9.4             True
# 14                 5            155   9.3             True
#
#     quantidade_avaliacoes  quantidade_alunos  carga_horaria
# 0                     299                631              8  \
# 1                    1469               3328             10
# 2                     571               1129              8
# 3                   36781              42509              6
# 4                   11748              22242              6
# 5                    4180               5983              4
# 6                   10629              20229              6
# 7                     341                726             12
# 8                    4268               6883             16
# 9                     392               1013             10
# 10                    188                413             14
# 11                    780               2373             10
# 12                    916               2149             10
# 13                     91                221              8
# 14                    136                467             10
#
#     quantidade_atividades data_criacao data_atualizacao
# 0                      45   2023-04-18       2023-05-15  \
# 1                      55   2022-12-01       2023-05-04
# 2                      44   2023-02-03       2023-04-28
# 3                      31   2019-05-02       2023-02-09
# 4                      50   2018-04-19       2023-05-18
# 5                      51   2018-05-14       2023-01-23
# 6                      62   2017-12-26       2023-05-15
# 7                      68   2021-07-05       2022-09-22
# 8                      76   2019-09-17       2023-03-21
# 9                      54   2022-11-03       2022-11-03
# 10                     57   2022-11-28       2022-11-28
# 11                     11   2018-04-06       2022-07-01
# 12                     15   2019-08-16       2022-03-18
# 13                     36   2022-02-23       2022-03-21
# 14                     49   2022-05-17       2022-06-09
#
#                                         video_1a_aula
# 0   https://video.alura.com.br/alura/811381867-sd....  \
# 1   https://video.alura.com.br/alura/769007907-sd....
# 2   https://video.alura.com.br/alura/788410424-sd....
# 3   https://video.alura.com.br/alura/754482117-sd....
# 4   https://video.alura.com.br/alura/261911673-sd....
# 5   https://video.alura.com.br/alura/264145113-sd....
# 6   https://video.alura.com.br/alura/247521704-sd....
# 7   https://video.alura.com.br/alura/563984183-sd....
# 8   https://video.alura.com.br/alura/359818375-sd....
# 9   https://video.alura.com.br/alura/756494726-sd....
# 10  https://video.alura.com.br/alura/756762507-sd....
# 11  https://video.alura.com.br/alura/263379099-sd....
# 12  https://video.alura.com.br/alura/346896274-sd....
# 13  https://video.alura.com.br/alura/673351738-sd....
# 14  https://video.alura.com.br/alura/705738035-sd....
#
#                                          publico_alvo
# 0   Qualquer pessoa com conhecimento em C#, banco ...  \
# 1   Profissionais que já atuam no desenvolvimento ...
# 2   Qualquer pessoa com conhecimento em C# e na cr...
# 3   Estudantes que buscam qualificação profissiona...
# 4   Pessoas com conhecimentos básicos em HTML e CS...
# 5   Front-enders que conheçam JavaScript preocupad...
# 6   Pessoas preocupadas com a acessibilidade em se...
# 7                                      Programadores.
# 8   Desenvolvedores (ou pessoas de qualquer outra ...
# 9   Profissional de Business Intelligence, Banco d...
# 10  Profissionais de Business Intelligence, Banco ...
# 11  Estudantes e motion designers que querem apren...
# 12  Designer ou estudantes de design que querem ap...
# 13  Estudantes e profissionais da área do design q...
# 14  Estudantes de design, comunicação e afins ou p...
#
#                                              chamadas
# 0   [Entenda conceitos de organização e separação ...  \
# 1   [Aprenda a receber requisições em sua API\r, E...
# 2   [Entenda como o Entity pode te ajudar a relaci...
# 3   [Aprenda como uma empresa aprende a ser Ágil\r...
# 4   [Melhore seu site para usuários de leitor de t...
# 5   [Melhore ainda mais seu site para usuários de ...
# 6   [Entenda porque pensar em acessibilidade;\r, P...
# 7   [Veja como manipular o BigQuery usando C#\r, A...
# 8   [Conheça qual é o papel do DBA\r, Faça um tuni...
# 9   [Aprenda a instalar o Oracle Database Enterpri...
# 10  [Aprenda como o banco de dados se organiza na ...
# 11  [Conheça uns dos principais plugins feitos pro...
# 12  [Aprenda a tratar as imagens para trabalhar no...
# 13  [Aprenda a utilizar o Illustrator para o iPad\...
# 14  [Aprenda como utilizar a ferramenta Shape Buil...
#
#                                                ementa
# 0   [{'capitulo': 'Conhecendo o Identity', 'secoes...  \
# 1   [{'capitulo': 'Entendendo o conceito', 'secoes...
# 2   [{'capitulo': 'Crescendo o projeto', 'secoes':...
# 3   [{'capitulo': 'Business Agility', 'secoes': ['...
# 4   [{'capitulo': 'HTML e os leitores de tela', 's...
# 5   [{'capitulo': 'Melhorias iniciais', 'secoes': ...
# 6   [{'capitulo': 'Acessibilidade e autismo', 'sec...
# 7   [{'capitulo': 'Instalação e confguração do amb...
# 8   [{'capitulo': 'Preparando o ambiente', 'secoes...
# 9   [{'capitulo': 'Instalando o Oracle', 'secoes':...
# 10  [{'capitulo': 'Estrutura do banco de dados', '...
# 11  [{'capitulo': 'Primeiro contato com o Element ...
# 12  [{'capitulo': 'introdução', 'secoes': ['Introd...
# 13  [{'capitulo': 'Primeiro contato', 'secoes': ['...
# 14  [{'capitulo': 'Definição do estilo e logotipo'...
#
#                                           instrutores carreiras musicas
# 0   [{'twitter': 'https://twitter.com/DanielArtine...        []      []  \
# 1   [{'twitter': 'https://twitter.com/DanielArtine...        []      []
# 2   [{'twitter': 'https://twitter.com/DanielArtine...        []      []
# 3   [{'twitter': 'axmagno', 'linkedin': 'https://w...        []      []
# 4   [{'twitter': 'https://twitter.com/designernata...        []      []
# 5   [{'twitter': 'https://twitter.com/designernata...        []      []
# 6   [{'twitter': 'https://twitter.com/designernata...        []      []
# 7   [{'twitter': '', 'linkedin': 'https://www.link...        []      []
# 8   [{'twitter': '', 'linkedin': 'https://www.link...        []      []
# 9   [{'twitter': '', 'linkedin': 'https://www.link...        []      []
# 10  [{'twitter': '', 'linkedin': 'https://www.link...        []      []
# 11  [{'twitter': 'https://twitter.com/gaveta', 'li...        []      []
# 12  [{'twitter': 'https://twitter.com/GuguHorn', '...        []      []
# 13  [{'twitter': '', 'linkedin': 'https://www.link...        []      []
# 14  [{'twitter': '', 'linkedin': 'https://www.link...        []      []
#
#                                           depoimentos
# 0                                                  []  \
# 1                                                  []
# 2                                                  []
# 3   [{'texto': 'Um curso rápido, enxuto. O profess...
# 4   [{'texto': 'Eu não imaginava que as coisas fun...
# 5   [{'texto': 'Tive alguns impedimentos ao longo ...
# 6   [{'texto': 'Nunca soube de nenhum curso aponta...
# 7                                                  []
# 8   [{'texto': 'Nas telas onde existem exercícios ...
# 9                                                  []
# 10                                                 []
# 11  [{'texto': 'Adorei o curso, o gaveta arrebenta...
# 12  [{'texto': 'adorei como ele fez as animações e...
# 13                                                 []
# 14                                                 []
#
#                                             formacoes curso_substituto
# 0   [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...             None  \
# 1   [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...             None
# 2   [{'codigo': 'dotnet', 'cor': '#00c86f', 'titul...             None
# 3   [{'codigo': 'business-agility', 'cor': '#ff8c2...             None
# 4   [{'codigo': 'acessibilidade-web', 'cor': '#6bd...             None
# 5   [{'codigo': 'acessibilidade-web', 'cor': '#6bd...             None
# 6   [{'codigo': 'acessibilidade-web', 'cor': '#6bd...             None
# 7   [{'codigo': 'google-bigquery-datastudio', 'cor...             None
# 8   [{'codigo': 'oracle-mysql', 'cor': '#9cd33b', ...             None
# 9   [{'codigo': 'oracle-database-administracao-per...             None
# 10  [{'codigo': 'oracle-database-administracao-per...             None
# 11  [{'codigo': 'motion-design', 'cor': '#dc6ebe',...             None
# 12  [{'codigo': 'motion-design', 'cor': '#dc6ebe',...             None
# 13  [{'codigo': 'adobe-mobile', 'cor': '#dc6ebe', ...             None
# 14  [{'codigo': 'grafica-illustrator', 'cor': '#dc...             None
#
#                                             parceiros
# 0                                                  []  \
# 1                                                  []
# 2                                                  []
# 3   [{'imageUrl': 'https://cdn1.gnarususercontent....
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11  [{'imageUrl': 'https://cdn1.gnarususercontent....
# 12                                                 []
# 13                                                 []
# 14                                                 []
#
#                                         requerimentos highlightedExtraField
# 0                    [.NET 6: relacionando entidades]                        \
# 1        [HTTP: entendendo a web por baixo dos panos]
# 2                       [.NET 6: criando uma web API]
# 3                                                  []
# 4   [HTML e CSS: ambientes de desenvolvimento, est...
# 5   [JavaScript e HTML: desenvolva um jogo e prati...
# 6                                                  []
# 7                    [BigQuery: manipulação de dados]
# 8        [Procedures SQL: executando código no MySQL]
# 9                 [Oracle PL/SQL: dominando packages]
# 10  [Administração do Oracle Database: criação e g...
# 11                                                 []
# 12                                                 []
# 13              [Adobe Illustrator: desenho vetorial]
# 14              [Adobe Illustrator: desenho vetorial]
#
#                                        transcriptions     categoria.nome
# 0   [{'sectionName': 'Conhecendo o Identity', 'tas...        Programação  \
# 1   [{'sectionName': 'Entendendo o conceito', 'tas...        Programação
# 2   [{'sectionName': 'Crescendo o projeto', 'taskN...        Programação
# 3   [{'sectionName': 'Business Agility', 'taskName...  Inovação & Gestão
# 4   [{'sectionName': 'HTML e os leitores de tela',...          Front-end
# 5   [{'sectionName': 'Melhorias iniciais', 'taskNa...          Front-end
# 6   [{'sectionName': 'Acessibilidade e autismo', '...          Front-end
# 7   [{'sectionName': 'Instalação e confguração do ...       Data Science
# 8   [{'sectionName': 'O papel do DBA', 'taskName':...       Data Science
# 9   [{'sectionName': 'Instalando o Oracle', 'taskN...       Data Science
# 10  [{'sectionName': 'Estrutura do banco de dados'...       Data Science
# 11  [{'sectionName': 'Primeiro contato com o Eleme...        UX & Design
# 12  [{'sectionName': 'Introdução', 'taskName': 'In...        UX & Design
# 13  [{'sectionName': 'Conhecendo o App', 'taskName...        UX & Design
# 14  [{'sectionName': 'Definição do estilo e logoti...        UX & Design
#
#      categoria.slug  categoria.ordem categoria.cor categoria.cor_auxiliar
# 0       programacao                0          None                   None  \
# 1       programacao                0          None                   None
# 2       programacao                0          None                   None
# 3   inovacao-gestao                0          None                   None
# 4         front-end                0          None                   None
# 5         front-end                0          None                   None
# 6         front-end                0          None                   None
# 7      data-science                0          None                   None
# 8      data-science                0          None                   None
# 9      data-science                0          None                   None
# 10     data-science                0          None                   None
# 11        design-ux                0          None                   None
# 12        design-ux                0          None                   None
# 13        design-ux                0          None                   None
# 14        design-ux                0          None                   None
#
#    categoria.subcategorias categoria.cursos categoria.numero_cursos
# 0                     None             None                    None  \
# 1                     None             None                    None
# 2                     None             None                    None
# 3                     None             None                    None
# 4                     None             None                    None
# 5                     None             None                    None
# 6                     None             None                    None
# 7                     None             None                    None
# 8                     None             None                    None
# 9                     None             None                    None
# 10                    None             None                    None
# 11                    None             None                    None
# 12                    None             None                    None
# 13                    None             None                    None
# 14                    None             None                    None
#
#    categoria.guides   subcategoria.slug     subcategoria.nome
# 0              None              dotnet                  .NET  \
# 1              None              dotnet                  .NET
# 2              None              dotnet                  .NET
# 3              None  transformacao-agil    Transformação Ágil
# 4              None            html-css            HTML e CSS
# 5              None            html-css            HTML e CSS
# 6              None            html-css            HTML e CSS
# 7              None               nosql                 NoSQL
# 8              None                 sql  SQL e Banco de Dados
# 9              None                 sql  SQL e Banco de Dados
# 10             None                 sql  SQL e Banco de Dados
# 11             None              motion         Motion Design
# 12             None            animacao              Animação
# 13             None      design-grafico        Design Gráfico
# 14             None      design-grafico        Design Gráfico
#
#    subcategoria.metaTitle subcategoria.metaDescription
# 0                    None                         None  \
# 1                    None                         None
# 2                    None                         None
# 3                    None                         None
# 4                    None                         None
# 5                    None                         None
# 6                    None                         None
# 7                    None                         None
# 8                    None                         None
# 9                    None                         None
# 10                   None                         None
# 11                   None                         None
# 12                   None                         None
# 13                   None                         None
# 14                   None                         None
#
#    subcategoria.description subcategoria.guides subcategoria.cursos
# 0                      None                                      []  \
# 1                      None                                      []
# 2                      None                                      []
# 3                      None                                      []
# 4                      None                                      []
# 5                      None                                      []
# 6                      None                                      []
# 7                      None                                      []
# 8                      None                                      []
# 9                      None                                      []
# 10                     None                                      []
# 11                     None                                      []
# 12                     None                                      []
# 13                     None                                      []
# 14                     None                                      []
#
#                                  alunos_ativos.alunos  alunos_ativos.total
# 0   [{'username': 'felipeedc29', 'nome': 'Felipe E...                418.0  \
# 1   [{'username': 'itamarbb1', 'nome': 'Itamar Ber...               1039.0
# 2   [{'username': 'hufesouza', 'nome': 'Hugo Ferre...                399.0
# 3   [{'username': 'aluizb91', 'nome': 'Andre Luiz ...               1851.0
# 4   [{'username': 'matheusw3314', 'nome': 'Matheus...               1136.0
# 5   [{'username': 'rodrigo-luz-e-silva', 'nome': '...                142.0
# 6   [{'username': 'natan-souza', 'nome': 'Natan So...               1084.0
# 7                                                 NaN                  NaN
# 8   [{'username': 'luzoliveiralais', 'nome': 'Lais...                818.0
# 9   [{'username': 'lucas-dpaula', 'nome': 'Lucas E...                188.0
# 10  [{'username': 'davi-fernandesd', 'nome': 'Davi...                 88.0
# 11  [{'username': 'douglasymide', 'nome': 'Douglas...                 74.0
# 12  [{'username': 'larissabritogarcia', 'nome': 'L...                 95.0
# 13                                                NaN                  NaN
# 14  [{'username': 'oademircastanha', 'nome': 'Adem...                 76.0
#
#     alunos_ativos
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN

# %% [markdown]
# Removendo colunas que não serão usadas.

# %%
cursos_pd = cursos_pd[
    [
        "id",
        "nome",
        "categoria.nome",
        "subcategoria.nome",
        "quantidade_alunos",
        "alunos_ativos.total",
        "nota_disponivel",
        "nota",
    ]
]
cursos_pd = cursos_pd.rename(
    columns={
        "categoria.nome": "nome_categoria",
        "subcategoria.nome": "nome_subcategoria",
        "alunos_ativos.total": "alunos_ativos_total",
    },
)
cursos_pd
# Out:
#         id                                               nome
# 0     2974  .NET 6 e Identity: implementando controle de u...  \
# 1     2792                        .NET 6: criando uma web API
# 2     2876                     .NET 6: relacionando entidades
# 3     1091  A Empresa Ágil: introduzindo o Business Agilit...
# 4      805  Acessibilidade web parte 1: tornando seu front...
# ...    ...                                                ...
# 1415  1592  Wordpress: integração whatsapp e internacional...
# 1416  1554                     Wordpress: sites com Elementor
# 1417  2571            XDebug: ferramenta de debug e profiling
# 1418   655        YouTube: da concepção de um canal ao upload
# 1419  2493  YouTube: estratégias de sucesso para o seu neg...
#
#          nome_categoria   nome_subcategoria  quantidade_alunos
# 0           Programação                .NET                631  \
# 1           Programação                .NET               3328
# 2           Programação                .NET               1129
# 3     Inovação & Gestão  Transformação Ágil              42509
# 4             Front-end          HTML e CSS              22242
# ...                 ...                 ...                ...
# 1415          Front-end           WordPress               4548
# 1416          Front-end           WordPress              12750
# 1417        Programação                 PHP                670
# 1418        UX & Design     Edição de Vídeo               5936
# 1419  Inovação & Gestão        Social Media               1385
#
#       alunos_ativos_total  nota_disponivel  nota
# 0                   418.0             True   9.3
# 1                  1039.0             True   9.4
# 2                   399.0             True   9.2
# 3                  1851.0             True   9.3
# 4                  1136.0             True   9.2
# ...                   ...              ...   ...
# 1415                243.0             True   9.3
# 1416                894.0             True   9.4
# 1417                 69.0             True   9.3
# 1418                164.0             True   8.8
# 1419                138.0             True   9.1
#
# [1420 rows x 8 columns]

# %%
import plotly.express as px

px.histogram(cursos_pd, x="quantidade_alunos")

# %%
from numpy import inf


q50 = cursos_pd.quantidade_alunos.quantile(0.50)
q75 = cursos_pd.quantidade_alunos.quantile(0.75)

cursos_pd["popularidade"] = pd.cut(
    cursos_pd.quantidade_alunos,
    bins=[0, q50, q75, inf],
    labels=["Moderadamente Popular", "Popular", "Muito Popular"],
)
cursos_pd[["nome", "quantidade_alunos", "popularidade"]].sort_values(
    by="quantidade_alunos", ascending=False
).head(10)
# Out:
#                                                    nome  quantidade_alunos
# 799   Lógica de programação: comece em lógica com o ...             176228  \
# 706   JavaScript e HTML: desenvolva um jogo e pratiq...             154284
# 619         Hábitos: da produtividade às metas pessoais             116973
# 66           Agilidade: promovendo a transformação ágil             106142
# 293     Comunicação não violenta: consciência para agir              89002
# 1079                  Python: começando com a linguagem              88373
# 1195                    Scrum: agilidade em seu projeto              87572
# 295   Comunicação: como se expressar bem e ser compr...              86010
# 340      Data Science: analise e visualização de dados.              73750
# 575     Git e Github: controle e compartilhe seu código              72586
#
#        popularidade
# 799   Muito Popular
# 706   Muito Popular
# 619   Muito Popular
# 66    Muito Popular
# 293   Muito Popular
# 1079  Muito Popular
# 1195  Muito Popular
# 295   Muito Popular
# 340   Muito Popular
# 575   Muito Popular

# %%
cursos_pd.query("nota_disponivel").groupby("nome_categoria").agg(
    **{
        "Média": pd.NamedAgg(column="nota", aggfunc="mean"),
        "Mínimo": pd.NamedAgg(column="nota", aggfunc="min"),
        "Máximo": pd.NamedAgg(column="nota", aggfunc="max"),
        "Desvio padrao": pd.NamedAgg(column="nota", aggfunc="std"),
    }
).round(2).sort_values(by=["Média", "Máximo"]).style.format("{:.2f}").highlight_max(subset="Média", color="lightgreen")
# Out:
# <style type="text/css">
# #T_d17c5_row5_col0, #T_d17c5_row6_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d17c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d17c5_level0_col0" class="col_heading level0 col0" >Média</th>
#       <th id="T_d17c5_level0_col1" class="col_heading level0 col1" >Mínimo</th>
#       <th id="T_d17c5_level0_col2" class="col_heading level0 col2" >Máximo</th>
#       <th id="T_d17c5_level0_col3" class="col_heading level0 col3" >Desvio padrao</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >nome_categoria</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d17c5_level0_row0" class="row_heading level0 row0" >DevOps</th>
#       <td id="T_d17c5_row0_col0" class="data row0 col0" >9.20</td>
#       <td id="T_d17c5_row0_col1" class="data row0 col1" >8.70</td>
#       <td id="T_d17c5_row0_col2" class="data row0 col2" >9.50</td>
#       <td id="T_d17c5_row0_col3" class="data row0 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_d17c5_level0_row1" class="row_heading level0 row1" >Inovação & Gestão</th>
#       <td id="T_d17c5_row1_col0" class="data row1 col0" >9.20</td>
#       <td id="T_d17c5_row1_col1" class="data row1 col1" >8.70</td>
#       <td id="T_d17c5_row1_col2" class="data row1 col2" >9.50</td>
#       <td id="T_d17c5_row1_col3" class="data row1 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_d17c5_level0_row2" class="row_heading level0 row2" >Data Science</th>
#       <td id="T_d17c5_row2_col0" class="data row2 col0" >9.20</td>
#       <td id="T_d17c5_row2_col1" class="data row2 col1" >8.40</td>
#       <td id="T_d17c5_row2_col2" class="data row2 col2" >9.60</td>
#       <td id="T_d17c5_row2_col3" class="data row2 col3" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_d17c5_level0_row3" class="row_heading level0 row3" >Mobile</th>
#       <td id="T_d17c5_row3_col0" class="data row3 col0" >9.20</td>
#       <td id="T_d17c5_row3_col1" class="data row3 col1" >8.70</td>
#       <td id="T_d17c5_row3_col2" class="data row3 col2" >9.60</td>
#       <td id="T_d17c5_row3_col3" class="data row3 col3" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_d17c5_level0_row4" class="row_heading level0 row4" >Front-end</th>
#       <td id="T_d17c5_row4_col0" class="data row4 col0" >9.20</td>
#       <td id="T_d17c5_row4_col1" class="data row4 col1" >8.40</td>
#       <td id="T_d17c5_row4_col2" class="data row4 col2" >9.70</td>
#       <td id="T_d17c5_row4_col3" class="data row4 col3" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_d17c5_level0_row5" class="row_heading level0 row5" >Programação</th>
#       <td id="T_d17c5_row5_col0" class="data row5 col0" >9.30</td>
#       <td id="T_d17c5_row5_col1" class="data row5 col1" >8.50</td>
#       <td id="T_d17c5_row5_col2" class="data row5 col2" >9.60</td>
#       <td id="T_d17c5_row5_col3" class="data row5 col3" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_d17c5_level0_row6" class="row_heading level0 row6" >UX & Design</th>
#       <td id="T_d17c5_row6_col0" class="data row6 col0" >9.30</td>
#       <td id="T_d17c5_row6_col1" class="data row6 col1" >8.30</td>
#       <td id="T_d17c5_row6_col2" class="data row6 col2" >9.70</td>
#       <td id="T_d17c5_row6_col3" class="data row6 col3" >0.20</td>
#     </tr>
#   </tbody>
# </table>

# %%
cursos_pd.value_counts(
    subset=["nome_categoria", "nome_subcategoria"], normalize=True
).to_frame(name="Percentual").style.format({"Percentual": "{:.2%}"}).bar(
    subset=["Percentual"], color="lightblue"
)
# Out:
# <style type="text/css">
# #T_46317_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_46317_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 92.3%, transparent 92.3%);
# }
# #T_46317_row2_col0, #T_46317_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 86.5%, transparent 86.5%);
# }
# #T_46317_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 84.6%, transparent 84.6%);
# }
# #T_46317_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 82.7%, transparent 82.7%);
# }
# #T_46317_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 69.2%, transparent 69.2%);
# }
# #T_46317_row7_col0, #T_46317_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 61.5%, transparent 61.5%);
# }
# #T_46317_row9_col0, #T_46317_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 57.7%, transparent 57.7%);
# }
# #T_46317_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 55.8%, transparent 55.8%);
# }
# #T_46317_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 50.0%, transparent 50.0%);
# }
# #T_46317_row13_col0, #T_46317_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 48.1%, transparent 48.1%);
# }
# #T_46317_row15_col0, #T_46317_row16_col0, #T_46317_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 46.2%, transparent 46.2%);
# }
# #T_46317_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 44.2%, transparent 44.2%);
# }
# #T_46317_row19_col0, #T_46317_row20_col0, #T_46317_row21_col0, #T_46317_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 38.5%, transparent 38.5%);
# }
# #T_46317_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 36.5%, transparent 36.5%);
# }
# #T_46317_row24_col0, #T_46317_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 34.6%, transparent 34.6%);
# }
# #T_46317_row26_col0, #T_46317_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 32.7%, transparent 32.7%);
# }
# #T_46317_row28_col0, #T_46317_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 30.8%, transparent 30.8%);
# }
# #T_46317_row30_col0, #T_46317_row31_col0, #T_46317_row32_col0, #T_46317_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 28.8%, transparent 28.8%);
# }
# #T_46317_row34_col0, #T_46317_row35_col0, #T_46317_row36_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 26.9%, transparent 26.9%);
# }
# #T_46317_row37_col0, #T_46317_row38_col0, #T_46317_row39_col0, #T_46317_row40_col0, #T_46317_row41_col0, #T_46317_row42_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 25.0%, transparent 25.0%);
# }
# #T_46317_row43_col0, #T_46317_row44_col0, #T_46317_row45_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 23.1%, transparent 23.1%);
# }
# #T_46317_row46_col0, #T_46317_row47_col0, #T_46317_row48_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 21.2%, transparent 21.2%);
# }
# #T_46317_row49_col0, #T_46317_row50_col0, #T_46317_row51_col0, #T_46317_row52_col0, #T_46317_row53_col0, #T_46317_row54_col0, #T_46317_row55_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 19.2%, transparent 19.2%);
# }
# #T_46317_row56_col0, #T_46317_row57_col0, #T_46317_row58_col0, #T_46317_row59_col0, #T_46317_row60_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 17.3%, transparent 17.3%);
# }
# #T_46317_row61_col0, #T_46317_row62_col0, #T_46317_row63_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 15.4%, transparent 15.4%);
# }
# #T_46317_row64_col0, #T_46317_row65_col0, #T_46317_row66_col0, #T_46317_row67_col0, #T_46317_row68_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 13.5%, transparent 13.5%);
# }
# #T_46317_row69_col0, #T_46317_row70_col0, #T_46317_row71_col0, #T_46317_row72_col0, #T_46317_row73_col0, #T_46317_row74_col0, #T_46317_row75_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 11.5%, transparent 11.5%);
# }
# #T_46317_row76_col0, #T_46317_row77_col0, #T_46317_row78_col0, #T_46317_row79_col0, #T_46317_row80_col0, #T_46317_row81_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 9.6%, transparent 9.6%);
# }
# #T_46317_row82_col0, #T_46317_row83_col0, #T_46317_row84_col0, #T_46317_row85_col0, #T_46317_row86_col0, #T_46317_row87_col0, #T_46317_row88_col0, #T_46317_row89_col0, #T_46317_row90_col0, #T_46317_row91_col0, #T_46317_row92_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 7.7%, transparent 7.7%);
# }
# #T_46317_row93_col0, #T_46317_row94_col0, #T_46317_row95_col0, #T_46317_row96_col0, #T_46317_row97_col0, #T_46317_row98_col0, #T_46317_row99_col0, #T_46317_row100_col0, #T_46317_row101_col0, #T_46317_row102_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 5.8%, transparent 5.8%);
# }
# #T_46317_row103_col0, #T_46317_row104_col0, #T_46317_row105_col0, #T_46317_row106_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 3.8%, transparent 3.8%);
# }
# #T_46317_row107_col0, #T_46317_row108_col0, #T_46317_row109_col0, #T_46317_row110_col0, #T_46317_row111_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 1.9%, transparent 1.9%);
# }
# </style>
# <table id="T_46317">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46317_level0_col0" class="col_heading level0 col0" >Percentual</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >nome_categoria</th>
#       <th class="index_name level1" >nome_subcategoria</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46317_level0_row0" class="row_heading level0 row0" >UX & Design</th>
#       <th id="T_46317_level1_row0" class="row_heading level1 row0" >Design Gráfico</th>
#       <td id="T_46317_row0_col0" class="data row0 col0" >3.66%</td>
#     </tr>
#     <tr>
#       <th id="T_46317_level0_row1" class="row_heading level0 row1" rowspan="2">Programação</th>
#       <th id="T_46317_level1_row1" class="row_heading level1 row1" >Java</th>
#       <td id="T_46317_row1_col0" class="data row1 col0" >3.38%</td>
#     </tr>
#     <tr>
#       <th id="T_46317_level1_row2" class="row_heading level1 row2" >PHP</th>
#       <td id="T_46317_row2_col0" class="data row2 col0" >3.17%</td>
#     </tr>
#     <tr>
#       <th id="T_46317_level0_row3" class="row_heading level0 row3" rowspan="2">Data Science</th>
#       <th id="T_46317_level1_row3" class="row_heading level1 row3" >Business Intelligence</th>
#       <td id="T_46317_row3_col0" class="data row3 col0" >3.17%</td>
#     </tr>
#     <tr>
#       <th id="T_46317_level1_row4" class="row_heading level1 row4" >Machine Learning</th>
#       <td id="T_46317_row4_col0" class="data row4 col0" >3.10%</td>
#     </tr>
#     <tr>
#       <th id="T_46317_level0_row5" class="row_heading level0 row5" >Mobile</th>
#       <th id="T_46317_level1_row5" class="row_heading level1 row5" >Android</th>
#       <td id="T_46317_row5_col0" class="data row5 col0" >3.03%</td>
#     </tr>
#     <tr>
#       <th id="T_46317_level0_row6" class="row_heading level0 row6" >Front-end</th>
#       <th id="T_46317_level1_row6" class="row_heading level1 row6" >React</th>
#       <td id="T_46317_row6_col0" class="data row6 col0" >2.54%</td>
#     </tr>
#     <tr>
#       <th id="T_46317_level0_row7" class="row_heading level0 row7" >Data Science</th>
#       <th id="T_46317_level1_row7" class="row_heading level1 row7" >SQL e Banco de Dados</th>
#       <td id="T_46317_row7_col0" class="data row7 col0" >2.25%</td>
#     </tr>
#     <tr>
#       <th id="T_46317_level0_row8" class="row_heading level0 row8" >UX & Design</th>
#       <th id="T_46317_level1_row8" class="row_heading level1 row8" >Pintura Digital</th>
#       <td id="T_46317_row8_col0" class="data row8 col0" >2.25%</td>
#     </tr>
#     <
